# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
pd. set_option('display.max_columns', None)

# %%
test_df = pd.read_csv('testloan.csv')
train_df = pd.read_csv('trainloan.csv')

# %%
train_df.info
# Out:
# <bound method DataFrame.info of       Customer ID               Name Gender  Age  Income (USD)  \
# 0         C-36995   Frederica Shealy      F   56       1933.05
# 1         C-33999  America Calderone      M   32       4952.91
# 2          C-3770      Rosetta Verne      F   65        988.19
# 3         C-26480         Zoe Chitty      F   65           NaN
# 4         C-23459       Afton Venema      F   31       2614.77
# ...           ...                ...    ...  ...           ...
# 29995     C-43723  Angelyn Clevenger      M   38       4969.41
# 29996     C-32511       Silas Slaugh      M   20       1606.88
# 29997      C-5192       Carmelo Lone      F   49           NaN
# 29998     C-12172      Carolann Osby      M   38       2417.71
# 29999     C-33003  Bridget Garibaldi      F   63       3068.24
#
#       Income Stability            Profession     Type of Employment  \
# 0                  Low               Working            Sales staff
# ...

# %%
train_df.head()
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
test_df.head()
# Out:
#   Customer ID              Name Gender  Age  Income (USD) Income Stability  \
# 0     C-26247  Tandra Olszewski      F   47       3472.69              Low
# 1     C-35067     Jeannette Cha      F   57       1184.84              Low
# 2     C-34590      Keva Godfrey      F   52       1266.27              Low
# 3     C-16668      Elva Sackett      M   65       1369.72             High
# 4     C-12196    Sade Constable      F   60       1939.23             High
#
#              Profession Type of Employment    Location  \
# 0  Commercial associate           Managers  Semi-Urban
# 1               Working        Sales staff       Rural
# 2               Working                NaN  Semi-Urban
# 3             Pensioner                NaN       Rural
# 4             Pensioner                NaN       Urban
#
#    Loan Amount Request (USD)  Current Loan Expenses (USD) Expense Type 1  \
# 0                  137088.98                       396.72              N
# ...

# %%
train_orignal=train_df.copy()
test_orignal = test_df.copy()

# %%
train_df.info(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %%
train_df.head(5)
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
train_df['Gender'].value_counts()
# Out:
# M    15053
# F    14894
# Name: Gender, dtype: int64

# %%
train_df['Profession'].value_counts()
# Out:
# Working                 16926
# Commercial associate     7962
# Pensioner                2740
# State servant            2366
# Unemployed                  2
# Businessman                 2
# Maternity leave             1
# Student                     1
# Name: Profession, dtype: int64

# %%
train_df['Type of Employment'].value_counts()
# Out:
# Laborers                 5578
# Sales staff              3736
# Core staff               3230
# Managers                 2495
# Drivers                  1606
# Accountants              1379
# High skill tech staff    1307
# Medicine staff            864
# Security staff            579
# Cooking staff             566
# Private service staff     342
# Cleaning staff            341
# Low-skill Laborers        162
# Secretaries               161
# Waiters/barmen staff      149
# Realty agents              86
# IT staff                   77
# HR staff                   72
# Name: Type of Employment, dtype: int64

# %%
train_df['Location'].value_counts()
# Out:
# Semi-Urban    21563
# Rural          5338
# Urban          3099
# Name: Location, dtype: int64

# %%
train_df['Has Active Credit Card'].value_counts()
# Out:
# Active         9771
# Inactive       9466
# Unpossessed    9197
# Name: Has Active Credit Card, dtype: int64

# %%
train_df['Property Location'].value_counts()
# Out:
# Semi-Urban    10387
# Rural         10041
# Urban          9216
# Name: Property Location, dtype: int64

# %%
label_encoder1 = LabelEncoder()
label_encoder2 = LabelEncoder()
label_encoder3 = LabelEncoder()
label_encoder4 = LabelEncoder()
label_encoder5 = LabelEncoder()
label_encoder6 = LabelEncoder()
label_encoder7 = LabelEncoder()
label_encoder8 = LabelEncoder()
label_encoder9 = LabelEncoder()

# %%
train_df['Gender'] = label_encoder1.fit_transform(train_df['Gender'].astype(str))
test_df['Gender'] = label_encoder1.fit_transform(test_df['Gender'].astype(str))

# %%
train_df['Income Stability'] = label_encoder7.fit_transform(train_df['Income Stability'].astype(str))
test_df['Income Stability'] = label_encoder7.fit_transform(test_df['Income Stability'].astype(str))

# %%
train_df['Profession'] = label_encoder2.fit_transform(train_df['Profession'].astype(str))
test_df['Profession'] = label_encoder2.fit_transform(test_df['Profession'].astype(str))

# %%
train_df['Type of Employment'] = label_encoder3.fit_transform(train_df['Type of Employment'].astype(str))
test_df['Type of Employment'] = label_encoder3.fit_transform(test_df['Type of Employment'].astype(str))

# %%
train_df['Location'] = label_encoder4.fit_transform(train_df['Location'].astype(str))
test_df['Location'] = label_encoder4.fit_transform(test_df['Location'].astype(str))

# %%
train_df['Has Active Credit Card'] = label_encoder5.fit_transform(train_df['Has Active Credit Card'].astype(str))
test_df['Has Active Credit Card'] = label_encoder5.fit_transform(test_df['Has Active Credit Card'].astype(str))

# %%
train_df['Property Location'] = label_encoder6.fit_transform(train_df['Property Location'].astype(str))
test_df['Property Location'] = label_encoder6.fit_transform(test_df['Property Location'].astype(str))

# %%
train_df.head(10)
# Out:
#   Customer ID               Name  Gender  Age  Income (USD)  Income Stability  \
# 0     C-36995   Frederica Shealy       0   56       1933.05                 1
# 1     C-33999  America Calderone       1   32       4952.91                 1
# 2      C-3770      Rosetta Verne       0   65        988.19                 0
# 3     C-26480         Zoe Chitty       0   65           NaN                 0
# 4     C-23459       Afton Venema       0   31       2614.77                 1
# 5     C-17688     Polly Crumpler       0   60       1234.92                 1
# 6     C-23855   Nathalie Olivier       1   43       2361.56                 1
# 7     C-11006   Clarinda Montana       0   45           NaN                 1
# 8     C-26934       Kenny Ankrom       0   38       1296.07                 1
# 9     C-24944     Barbie Goetsch       1   18       1546.17                 1
#
#    Profession  Type of Employment  Location  Loan Amount Request (USD)  \
# ...

# %%
train_df['Expense Type 1'] = label_encoder8.fit_transform(train_df['Expense Type 1'].astype(str))
test_df['Expense Type 1'] = label_encoder8.fit_transform(test_df['Expense Type 1'].astype(str))

# %%
train_df['Expense Type 2'] = label_encoder9.fit_transform(train_df['Expense Type 2'].astype(str))
test_df['Expense Type 2'] = label_encoder9.fit_transform(test_df['Expense Type 2'].astype(str))

# %%
train_df.fillna(0,inplace=True)

test_df.fillna(0,inplace=True)

# %%
train_df.tail(10)
# Out:
#       Customer ID                Name  Gender  Age  Income (USD)  \
# 29990     C-49100    Chantel Costigan       0   64       4211.81
# 29991     C-20609         Barbie Hice       0   55          0.00
# 29992     C-32912           Nana Nell       1   34       2904.15
# 29993     C-21440  Jonathon Rodriques       1   62          0.00
# 29994      C-7813    Jocelyn Deschamp       1   39       2250.19
# 29995     C-43723   Angelyn Clevenger       1   38       4969.41
# 29996     C-32511        Silas Slaugh       1   20       1606.88
# 29997      C-5192        Carmelo Lone       0   49          0.00
# 29998     C-12172       Carolann Osby       1   38       2417.71
# 29999     C-33003   Bridget Garibaldi       0   63       3068.24
#
#        Income Stability  Profession  Type of Employment  Location  \
# 29990                 1           1                   2         2
# 29991                 1           1                   6         1
# ...

# %%
x_train=train_df.iloc[:,2:-1]
y_train=train_df.iloc[:,-1:]

# %%
x_train.columns
# Out:
# Index(['Gender', 'Age', 'Income (USD)', 'Income Stability', 'Profession',
#        'Type of Employment', 'Location', 'Loan Amount Request (USD)',
#        'Current Loan Expenses (USD)', 'Expense Type 1', 'Expense Type 2',
#        'Dependents', 'Credit Score', 'No. of Defaults',
#        'Has Active Credit Card', 'Property ID', 'Property Age',
#        'Property Type', 'Property Location', 'Co-Applicant', 'Property Price'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
test_df['Loan Sanction Amount (USD)']=dtr.predict(test_df.drop(['Customer ID','Name'],axis=1))# predictions
test_df
# Out:
#       Customer ID              Name  Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski       0   47       3472.69
# 1         C-35067     Jeannette Cha       0   57       1184.84
# 2         C-34590      Keva Godfrey       0   52       1266.27
# 3         C-16668      Elva Sackett       1   65       1369.72
# 4         C-12196    Sade Constable       0   60       1939.23
# ...           ...               ...     ...  ...           ...
# 19995      C-9076    Tobias Davilla       0   19       1349.60
# 19996     C-17587    Evelina Hodges       1   22       2019.78
# 19997     C-46479   Karlyn Mckinzie       1   19       2252.03
# 19998      C-3099    Mariana Pulver       0   21       1845.35
# 19999     C-43482   Mechelle Boddie       1   21       5233.16
#
#        Income Stability  Profession  Type of Employment  Location  \
# 0                     1           0                  10         1
# 1                     1           6                  14         0
# ...

# %%
test_df.replace(['?'],[0],inplace=True)

# %%
submit_df=test_df[['Customer ID','Loan Sanction Amount (USD)']]
submit_df
# Out:
#       Customer ID  Loan Sanction Amount (USD)
# 0         C-26247                   100324.13
# 1         C-35067                    84311.72
# 2         C-34590                        0.00
# 3         C-16668                    74045.36
# 4         C-12196                    73632.23
# ...           ...                         ...
# 19995      C-9076                        0.00
# 19996     C-17587                    31892.98
# 19997     C-46479                        0.00
# 19998      C-3099                    72669.91
# 19999     C-43482                    96160.07
#
# [20000 rows x 2 columns]

# %%
submit_df.to_csv('test_you_saquib.csv',index=False)
